# %%
import csv

# 인구 데이터 읽어와서 리스트로 저장하기
f1 = open('LOCAL_PEOPLE_DONG_201912.csv', encoding='utf8')    
data = csv.reader(f1)
next(data)
data = list(data)

# 행정동코드 데이터 불러와서 리스트로 저장하기
f2 = open('dong_code.csv', encoding='utf8')
code_data = csv.reader(f2)
next(code_data)
next(code_data)
code_data = list(code_data)

# 위치 데이터 불러와서 리스트로 저장하기
f3 = open('dong_location.csv')
location_data = csv.reader(f3)
next(location_data)
location_data = list(location_data)

# 인구데이터의 데이터타입 변경하기 
for row in data : 
    for i in range(1, 32) : 
        if i <= 2 : 
            row[i] = int(row[i])
        else : 
            row[i] = float(row[i])
            
# 행정동코드 데이터의 데이터 타입 변환하기
for row in code_data :
    row[0], row[1] = int(row[0]), int(row[1]) # 7자리 행정동코드, 8자리 행정동코드

# 위치 정보 데이터의 데이터 타입 변환하기
for row in location_data :
    row[2], row[-2], row[-1] = int(row[2]), float(row[-2]), float(row[-1])


# 2. 행정동별 인구수를 저장하는 빈 딕셔너리를 만들고 행정동별 총생활인구를 딕셔너리에 저장하기
dong_population = {}

for row in data: 
    dong_code, p = row[2], row[3]
    if dong_code not in dong_population.keys(): 
        dong_population[dong_code] = p
    else:
        dong_population[dong_code] += p
        
# print(dong_population) 


# 3. 인구수를 기준으로 내림차순 정렬하고, 앞에서 10개 항목만 별도로 저장하기
import operator

top10 = sorted(dong_population.items(), key=operator.itemgetter(1), reverse = True)[:10]
#print(top10)

top10_code8 = [t[0] for t in top10]
print(top10_code8)


top10_name = [0 for i in range(10)]
top10_lat  = [0 for i in range(10)]
top10_long = [0 for i in range(10)]

# 4. 8자리 행정동코드에 해당하는 행정동명 찾기
for i in range(len(top10_code8)) : 
    for row in code_data : 
        if row[1] == top10_code8[i] :  
            # 행정동명 리스트에 저장하기 
            top10_name[i] = row[-1]
    # 5. 행정동명에 해당하는 위도와 경도를 찾아 리스트에 저장하기
    for row in location_data : 
        if row[3] == top10_name[i] :
            top10_lat[i], top10_long[i] = row[-1], row[-2] 

print(top10_lat)
print(top10_long)


# 추가. 행정동명으로 위치 정보를 찾지 못하면 7자리 행정동코드로 찾기
for i in range(len(top10_lat)):
    # 위도나 경도가 0인 요소가 있다면
    if top10_lat[i] == 0 or top10_long[i] == 0 :
        # code_data에서 7자리 행정동코드를 구해 dong7에 저장하기
        for row in code_data :
            if top10_code8[i] == row[1] :
                dong7 = row[0]
        # location_data에서 7자리 행정동코드가 dong7인 행을 찾아 위도와 경도를 구하기
        for row in location_data : 
            if dong7 == row[2] :
                top10_lat[i], top10_long[i] = row[-1], row[-2] 

print(top10_lat)
print(top10_long)


# 6. 완성된 리스트 지도에 표시하기
import folium

for i in range(len(top10_name)) : 
    top10_name[i] = str(i+1)+'. '+top10_name[i]

    
map_top10 = folium.Map([top10_lat[0], top10_long[0]], zoom_start=12)
for i in range(10): 
    folium.Marker(
        [top10_lat[i], top10_long[i]], tooltip=top10_name[i],
        icon=folium.Icon(color='red', icon='star')
        ).add_to(map_top10)

map_top10
# Out:
# [11680640, 11560540, 11440660, 11110615, 11650530, 11410585, 11380690, 11545510, 11680650, 11680610]
# [37.4999211, 0, 37.5550337, 37.5777701, 37.4856591, 37.5659638, 37.64193, 37.4756389, 37.4984733, 37.4955294]
# [127.0367584, 0, 126.9228533, 126.9892737, 127.0097616, 126.9384315, 126.9387277, 126.8850721, 127.0449272, 127.0662436]
# [37.4999211, 37.5286662, 37.5550337, 37.5777701, 37.4856591, 37.5659638, 37.64193, 37.4756389, 37.4984733, 37.4955294]
# [127.0367584, 126.9290731, 126.9228533, 126.9892737, 127.0097616, 126.9384315, 126.9387277, 126.8850721, 127.0449272, 127.0662436]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4a9b88a32d430061338d267aa5531659 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4a9b88a32d430061338d267aa5531659&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4a9b88a32d430061338d267aa5531659 = L.map(
#                 &quot;map_4a9b88a32d430061338d267aa5531659&quot;,
#                 {
#                     center: [37.4999211, 127.0367584],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_927b87a2c023e33a9ba2602c13d9cc33 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_927b87a2c023e33a9ba2602c13d9cc33.addTo(map_4a9b88a32d430061338d267aa5531659);
#
#
#             var marker_66d3fcb62bfb4598362d7a6a697b3e31 = L.marker(
#                 [37.4999211, 127.0367584],
#                 {
# }
#             ).addTo(map_4a9b88a32d430061338d267aa5531659);
#
#
#             var icon_e92b99cab11ccba76bbdeae109ec3436 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;star&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_66d3fcb62bfb4598362d7a6a697b3e31.bindTooltip(
#                 `&lt;div&gt;
#                      1. 역삼1동
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_66d3fcb62bfb4598362d7a6a697b3e31.setIcon(icon_e92b99cab11ccba76bbdeae109ec3436);
#
#
#             var marker_7b3a29e517b9b711fc0ddad82bca4f3e = L.marker(
#                 [37.5286662, 126.9290731],
#                 {
# }
#             ).addTo(map_4a9b88a32d430061338d267aa5531659);
#
#
#             var icon_a2040a4d9777c03aabad8cb2cdda2aae = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;star&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_7b3a29e517b9b711fc0ddad82bca4f3e.bindTooltip(
#                 `&lt;div&gt;
#                      2. 여의동
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_7b3a29e517b9b711fc0ddad82bca4f3e.setIcon(icon_a2040a4d9777c03aabad8cb2cdda2aae);
#
#
#             var marker_5b32fe67e9e2d913b37934d4f7e91227 = L.marker(
#                 [37.5550337, 126.9228533],
#                 {
# }
#             ).addTo(map_4a9b88a32d430061338d267aa5531659);
#
#
#             var icon_b67137cb2e57019137721a0d2f4a9269 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;star&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_5b32fe67e9e2d913b37934d4f7e91227.bindTooltip(
#                 `&lt;div&gt;
#                      3. 서교동
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_5b32fe67e9e2d913b37934d4f7e91227.setIcon(icon_b67137cb2e57019137721a0d2f4a9269);
#
#
#             var marker_e2fb1f101629a608bf6a37cb6f90d838 = L.marker(
#                 [37.5777701, 126.9892737],
#                 {
# }
#             ).addTo(map_4a9b88a32d430061338d267aa5531659);
#
#
#             var icon_6829a027c1fa69a369e823b7a0dda515 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;star&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_e2fb1f101629a608bf6a37cb6f90d838.bindTooltip(
#                 `&lt;div&gt;
#                      4. 종로1.2.3.4가동
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_e2fb1f101629a608bf6a37cb6f90d838.setIcon(icon_6829a027c1fa69a369e823b7a0dda515);
#
#
#             var marker_9703908517e92000fda3e2ed8e6e0fae = L.marker(
#                 [37.4856591, 127.0097616],
#                 {
# }
#             ).addTo(map_4a9b88a32d430061338d267aa5531659);
#
#
#             var icon_ca630

# %%
# 추가 분석 : 남성이 많은 지역과 여성이 많은 지역 비교하기
import csv

# 인구 데이터 읽어와서 리스트로 저장하기
f1 = open('LOCAL_PEOPLE_DONG_201912.csv', encoding='utf8')    
data = csv.reader(f1)
next(data)
data = list(data)

# 행정동코드 데이터 불러와서 리스트로 저장하기
f2 = open('dong_code.csv', encoding='utf8')
code_data = csv.reader(f2)
next(code_data)
next(code_data)
code_data = list(code_data)

# 위치 데이터 불러와서 리스트로 저장하기
f3 = open('dong_location.csv')
location_data = csv.reader(f3)
next(location_data)
location_data = list(location_data)

# 인구데이터의 데이터타입 변경하기 
for row in data : 
    for i in range(1, 32) : 
        if i <= 2 : 
            row[i] = int(row[i])
        else : 
            row[i] = float(row[i])
            
# 행정동코드 데이터의 데이터 타입 변환하기
for row in code_data :
    row[0], row[1] = int(row[0]), int(row[1]) # 7자리 행정동코드, 8자리 행정동코드

# 위치 정보 데이터의 데이터 타입 변환하기
for row in location_data :
    row[2], row[-2], row[-1] = int(row[2]), float(row[-2]), float(row[-1])

# 2. 인구 데이터를 읽으며 행정동별 남성 인구수를 저장하는 딕셔너리 완성하기
dong_population = {}

for row in data: 
    # 남성 인구수를 저장하는 변수 p
    dong_code, p = row[2], sum(row[4:18])
    if dong_code not in dong_population.keys(): 
        dong_population[dong_code] = p
    else:
        dong_population[dong_code] += p
        
# print(dong_population) 

# 3. 인구수를 기준으로 내림차순 정렬하고, 앞에서 10개 항목만 별도로 저장하기
import operator

top10 = sorted(dong_population.items(), key=operator.itemgetter(1), reverse = True)[:10]
#print(top10)

top10_code8 = [t[0] for t in top10]
print(top10_code8)


top10_name = [0 for i in range(10)]
top10_lat  = [0 for i in range(10)]
top10_long = [0 for i in range(10)]

# 4. 8자리 행정동코드에 해당하는 행정동명 찾기
for i in range(len(top10_code8)) : 
    for row in code_data : 
        if row[1] == top10_code8[i] :  
            # 행정동명 리스트에 저장하기 
            top10_name[i] = row[-1]
    # 5. 행정동명에 해당하는 위도와 경도를 찾아 리스트에 저장하기
    for row in location_data : 
        if row[3] == top10_name[i] :
            top10_lat[i], top10_long[i] = row[-1], row[-2] 

print(top10_lat)
print(top10_long)


# 추가. 행정동명으로 위치 정보를 찾지 못하면 7자리 행정동코드로 찾기
for i in range(len(top10_lat)):
    # 위도나 경도가 0인 요소가 있다면
    if top10_lat[i] == 0 or top10_long[i] == 0 :
        # code_data에서 7자리 행정동코드를 구해 dong7에 저장하기
        for row in code_data :
            if top10_code8[i] == row[1] :
                dong7 = row[0]
        # location_data에서 7자리 행정동코드가 dong7인 행을 찾아 위도와 경도를 구하기
        for row in location_data : 
            if dong7 == row[2] :
                top10_lat[i], top10_long[i] = row[-1], row[-2] 

print(top10_lat)
print(top10_long)


# 6. 완성된 리스트 지도에 표시하기
import folium

for i in range(len(top10_name)) : 
    top10_name[i] = str(i+1)+'. '+top10_name[i]

    
map_top10 = folium.Map([top10_lat[0], top10_long[0]], zoom_start=12) 
for i in range(10):
    # 1~5위 지역은 진한 파란색, 6~7위 지역은 연한 파란색으로 표시하기
    if i < 5: 
        folium.Marker(
            [top10_lat[i], top10_long[i]], tooltip=top10_name[i], 
            icon=folium.Icon(color='darkblue', icon='male', prefix='fa')
        ).add_to(map_top10)
    else: 
        folium.Marker(
            [top10_lat[i], top10_long[i]], tooltip=top10_name[i], 
            icon=folium.Icon(color='lightblue', icon='male', prefix='fa') 
        ).add_to(map_top10)

map_top10
# Out:
# [11680640, 11560540, 11110615, 11440660, 11650530, 11545510, 11380690, 11680610, 11410585, 11680650]
# [37.4999211, 0, 37.5777701, 37.5550337, 37.4856591, 37.4756389, 37.64193, 37.4955294, 37.5659638, 37.4984733]
# [127.0367584, 0, 126.9892737, 126.9228533, 127.0097616, 126.8850721, 126.9387277, 127.0662436, 126.9384315, 127.0449272]
# [37.4999211, 37.5286662, 37.5777701, 37.5550337, 37.4856591, 37.4756389, 37.64193, 37.4955294, 37.5659638, 37.4984733]
# [127.0367584, 126.9290731, 126.9892737, 126.9228533, 127.0097616, 126.8850721, 126.9387277, 127.0662436, 126.9384315, 127.0449272]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0f84775f9f4265d6182c5fd501d823b0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0f84775f9f4265d6182c5fd501d823b0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0f84775f9f4265d6182c5fd501d823b0 = L.map(
#                 &quot;map_0f84775f9f4265d6182c5fd501d823b0&quot;,
#                 {
#                     center: [37.4999211, 127.0367584],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2c992a1fe413838febf53df4eb8acc69 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2c992a1fe413838febf53df4eb8acc69.addTo(map_0f84775f9f4265d6182c5fd501d823b0);
#
#
#             var marker_f07cf2022649e63f31955bb3b87e03a1 = L.marker(
#                 [37.4999211, 127.0367584],
#                 {
# }
#             ).addTo(map_0f84775f9f4265d6182c5fd501d823b0);
#
#
#             var icon_828b4b56a7e3e69b1d4e03413ea451ab = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;male&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_f07cf2022649e63f31955bb3b87e03a1.bindTooltip(
#                 `&lt;div&gt;
#                      1. 역삼1동
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_f07cf2022649e63f31955bb3b87e03a1.setIcon(icon_828b4b56a7e3e69b1d4e03413ea451ab);
#
#
#             var marker_faa76269fa33e55beee58c134a3472af = L.marker(
#                 [37.5286662, 126.9290731],
#                 {
# }
#             ).addTo(map_0f84775f9f4265d6182c5fd501d823b0);
#
#
#             var icon_4e9e6cb9fa5541402b1814ad668b2575 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;male&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_faa76269fa33e55beee58c134a3472af.bindTooltip(
#                 `&lt;div&gt;
#                      2. 여의동
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_faa76269fa33e55beee58c134a3472af.setIcon(icon_4e9e6cb9fa5541402b1814ad668b2575);
#
#
#             var marker_59ef84eaed933eed1ca58ac89efeb40f = L.marker(
#                 [37.5777701, 126.9892737],
#                 {
# }
#             ).addTo(map_0f84775f9f4265d6182c5fd501d823b0);
#
#
#             var icon_05113f07efe94d68558f2c21de713854 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;male&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_59ef84eaed933eed1ca58ac89efeb40f.bindTooltip(
#                 `&lt;div&gt;
#                      3. 종로1.2.3.4가동
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_59ef84eaed933eed1ca58ac89efeb40f.setIcon(icon_05113f07efe94d68558f2c21de713854);
#
#
#             var marker_795420d557f1f49f9a4404dd1a9c49a3 = L.marker(
#                 [37.5550337, 126.9228533],
#                 {
# }
#             ).addTo(map_0f84775f9f4265d6182c5fd501d823b0);
#
#
#             var icon_5b6f925d5e52cb581909954b9cb5358e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;male&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_795420d557f1f49f9a4404dd1a9c49a3.bindTooltip(
#                 `&lt;div&gt;
#                      4. 서교동
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_795420d557f1f49f9a4404dd1a9c49a3.setIcon(icon_5b6f925d5e52cb581909954b9cb5358e);
#
#
#             var marker_6f26e5c34f86c67d091cab83eece3a13 = L.marker(
#                 [37.4856591, 127.0097616],
#                 {
# }
#             ).addTo(map_0f84775f9f4265d6182c5fd501d823b0);
#
#
#             var icon_a33a21c6bda1e

# %%
# 2. 인구 데이터를 읽으며 행정동별 여성 인구수를 저장하는 딕셔너리 완성하기
dong_population = {}

for row in data: 
    # 여성 인구수를 저장하는 변수 p
    dong_code, p = row[2], sum(row[18:32])
    if dong_code not in dong_population.keys(): 
        dong_population[dong_code] = p
    else:
        dong_population[dong_code] += p
        
# print(dong_population) 


# 3. 인구수를 기준으로 내림차순 정렬하고, 앞에서 10개 항목만 별도로 저장하기
import operator

top10 = sorted(dong_population.items(), key=operator.itemgetter(1), reverse = True)[:10]
#print(top10)

top10_code8 = [t[0] for t in top10]
print(top10_code8)


top10_name = [0 for i in range(10)]
top10_lat  = [0 for i in range(10)]
top10_long = [0 for i in range(10)]

# 4. 8자리 행정동코드에 해당하는 행정동명 찾기
for i in range(len(top10_code8)) : 
    for row in code_data : 
        if row[1] == top10_code8[i] :  
            # 행정동명 리스트에 저장하기 
            top10_name[i] = row[-1]
    # 5. 행정동명에 해당하는 위도와 경도를 찾아 리스트에 저장하기
    for row in location_data : 
        if row[3] == top10_name[i] :
            top10_lat[i], top10_long[i] = row[-1], row[-2] 

print(top10_lat)
print(top10_long)

# 추가. 행정동명으로 위치 정보를 찾지 못하면 7자리 행정동코드로 찾기
for i in range(len(top10_lat)):
    # 위도나 경도가 0인 요소가 있다면
    if top10_lat[i] == 0 or top10_long[i] == 0 :
        # code_data에서 7자리 행정동코드를 구해 dong7에 저장하기
        for row in code_data :
            if top10_code8[i] == row[1] :
                dong7 = row[0]
        # location_data에서 7자리 행정동코드가 dong7인 행을 찾아 위도와 경도를 구하기
        for row in location_data : 
            if dong7 == row[2] :
                top10_lat[i], top10_long[i] = row[-1], row[-2] 

print(top10_lat)
print(top10_long)

# 6. 완성된 리스트 지도에 표시하기
import folium

for i in range(len(top10_name)) : 
    top10_name[i] = str(i+1)+'. '+top10_name[i]

    
map_top10 = folium.Map([top10_lat[0], top10_long[0]], zoom_start=12) 
for i in range(10):
    # 1~5위 지역은 진한 파란색, 6~7위 지역은 연한 파란색으로 표시하기
    if i < 5: 
        folium.Marker(
            [top10_lat[i], top10_long[i]], tooltip=top10_name[i], 
            icon=folium.Icon(color='red', icon='female', prefix='fa')
        ).add_to(map_top10)
    else: 
        folium.Marker(
            [top10_lat[i], top10_long[i]], tooltip=top10_name[i], 
            icon=folium.Icon(color='pink', icon='female', prefix='fa') 
        ).add_to(map_top10)

map_top10
# Out:
# [11680640, 11560540, 11440660, 11410585, 11380690, 11650530, 11110615, 11680650, 11740685, 11590530]
# [37.4999211, 0, 37.5550337, 37.5659638, 37.64193, 37.4856591, 37.5777701, 37.4984733, 37.5398758, 37.4999435]
# [127.0367584, 0, 126.9228533, 126.9384315, 126.9387277, 127.0097616, 126.9892737, 127.0449272, 127.1473638, 126.9543551]
# [37.4999211, 37.5286662, 37.5550337, 37.5659638, 37.64193, 37.4856591, 37.5777701, 37.4984733, 37.5398758, 37.4999435]
# [127.0367584, 126.9290731, 126.9228533, 126.9384315, 126.9387277, 127.0097616, 126.9892737, 127.0449272, 127.1473638, 126.9543551]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ee8fee429e21c38a14c832f5185f9bed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ee8fee429e21c38a14c832f5185f9bed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ee8fee429e21c38a14c832f5185f9bed = L.map(
#                 &quot;map_ee8fee429e21c38a14c832f5185f9bed&quot;,
#                 {
#                     center: [37.4999211, 127.0367584],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cc3ce7bf93b98b548ac5a35f5b4e6d9d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cc3ce7bf93b98b548ac5a35f5b4e6d9d.addTo(map_ee8fee429e21c38a14c832f5185f9bed);
#
#
#             var marker_ba8494e4bd068d44d5fad3d62038a869 = L.marker(
#                 [37.4999211, 127.0367584],
#                 {
# }
#             ).addTo(map_ee8fee429e21c38a14c832f5185f9bed);
#
#
#             var icon_fc8ebaa5caa98bb59300d6b10105c81a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;female&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_ba8494e4bd068d44d5fad3d62038a869.bindTooltip(
#                 `&lt;div&gt;
#                      1. 역삼1동
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_ba8494e4bd068d44d5fad3d62038a869.setIcon(icon_fc8ebaa5caa98bb59300d6b10105c81a);
#
#
#             var marker_9c1bbd7255f1851a540223a5260e2646 = L.marker(
#                 [37.5286662, 126.9290731],
#                 {
# }
#             ).addTo(map_ee8fee429e21c38a14c832f5185f9bed);
#
#
#             var icon_3b52ded26cdc149b404188728cd359e3 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;female&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_9c1bbd7255f1851a540223a5260e2646.bindTooltip(
#                 `&lt;div&gt;
#                      2. 여의동
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_9c1bbd7255f1851a540223a5260e2646.setIcon(icon_3b52ded26cdc149b404188728cd359e3);
#
#
#             var marker_1a4b46cfa4f53e9571d7209f4f07bbf1 = L.marker(
#                 [37.5550337, 126.9228533],
#                 {
# }
#             ).addTo(map_ee8fee429e21c38a14c832f5185f9bed);
#
#
#             var icon_9aed2167587646e144ecd46efc36c23b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;female&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_1a4b46cfa4f53e9571d7209f4f07bbf1.bindTooltip(
#                 `&lt;div&gt;
#                      3. 서교동
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_1a4b46cfa4f53e9571d7209f4f07bbf1.setIcon(icon_9aed2167587646e144ecd46efc36c23b);
#
#
#             var marker_104dbbeb02829c8bbf9f4a177a57657d = L.marker(
#                 [37.5659638, 126.9384315],
#                 {
# }
#             ).addTo(map_ee8fee429e21c38a14c832f5185f9bed);
#
#
#             var icon_8d3d290bb7b0391c08439553275ac39d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;female&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_104dbbeb02829c8bbf9f4a177a57657d.bindTooltip(
#                 `&lt;div&gt;
#                      4. 신촌동
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_104dbbeb02829c8bbf9f4a177a57657d.setIcon(icon_8d3d290bb7b0391c08439553275ac39d);
#
#
#             var marker_ab5f43f6698b74c6d426cc717f9ab383 = L.marker(
#                 [37.64193, 126.9387277],
#                 {
# }
#             ).addTo(map_ee8fee429e21c38a14c832f5185f9bed);
#
#
#             var icon_c96983fe7671d4df55fe9a152f0fbcb1 =
